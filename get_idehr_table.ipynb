# %%
import pandas as pd 
from utils import *

# %%
files = [
        'care_translated.xlsx',
        'hospice_therapy_translated.xlsx',
        'input_table_translated.xlsx',
        'obs_table_translated.xlsx',
        'outcome_translated.xlsx'
        ]

# %%
table = get_table(files)
table
# Out:
# ['IDCam' 'IDEHR' 'Author_Insert' 'TimeStamp_Insert' 'IDAccess' 'EHRType'
#  'PatientID' 'IDDigitalSignDocument' 'Not detectable'
#  'Note_Non_Rilevabile' 'Cam' 'IDGESTIONE_AUSILI' 'ds_ncons' 'ds_nbolla'
#  'dt_consegna' 'ds_nritiro' 'dt_ritiro' 'opt_annulla_consegna' 'ds_note_x'
#  'dt_Ric_consegna' 'dt_ric_cons_forn' 'dt_ric_ritiro' 'dt_ric_ritiro_forn'
#  'opt_ausilio' 'IDTERAPIE_OUTPAT_VIDAS' 'ds_altro_farmaco' 'ds_dose'
#  'opt_via_di_somm' 'ds_ora' 'dt_data_fine' 'dt_data_inizio' 'ds_note_y'
#  'opt_pregressa' 'opt_somm_terapia' 'opt_estemporanea' 'opt_termina'
#  'opt_somm_in_pompa' 'opt_farmaco' 'Note_al_bisogno']
# ['PatientID' 'IDBac' 'EHRID' 'Age' 'Sex' 'StartOfHospitalization'
#  'EndOfHospitalization' 'Diagnosis' 'TipeOfTherapy' 'DrugName' 'DrugCode'
#  'ATCCode' 'ComplementaryCodeDose' 'ActiveIngredient' 'Packacing'
#  'TypeOfUsage' 'Dose' 'HoursString' 'MaxDose' 'Frequency' 'DateTherapy'
#  'Duration']
# [' N/A' 'Unnamed: 0_x' 'IDANAMNESI_INF' 'IDEHR' 'Author_Insert'
# ...
